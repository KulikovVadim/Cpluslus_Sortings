# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [10, 100, 1000, 10000, 100000]
y = [0.00096, 0.00525, 5.86742, 561.985, 46045.43]
fig, ax = plt.subplots ()
ax.plot (x,y, marker='o')
ax.set_title ('duration of bubblе sort')
ax.set_xlabel ("elements")
ax.set_ylabel ("time, ms")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = [10, 100, 1000, 10000, 100000]
y = [0.00023, 0.0324, 1.5242, 95.235, 5205.24]
fig, ax = plt.subplots ()
ax.plot (x,y, marker='o')
ax.set_title ('duration of selection sort')
ax.set_xlabel ("elements")
ax.set_ylabel ("time, ms")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = [10, 100, 1000, 10000, 100000]
y = [0.00013, 0.0056, 0.86742, 61.985, 4605.4]
fig, ax = plt.subplots ()
ax.plot (x,y, marker='o')
ax.set_title ('duration of insertion sort')
ax.set_xlabel ("elements")
ax.set_ylabel ("time, ms")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
